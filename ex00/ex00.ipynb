# %% [markdown]
# # Exercise 0: Environment and libraries
#
# Minimal environment check for Python `>= 3.9` with `jupyter`, `numpy` and `pandas`.

# %% [markdown]
# Suggested setup:
#
# ```bash
# python -m venv ex00
# ex00\\Scripts\\activate
# python -m pip install -r ../requirements.txt
# ```

# %%
import sys

print("Python:", sys.version.split()[0])
print("Python >= 3.9:", sys.version_info >= (3, 9))
# Out:
# Python: 3.13.5
# Python >= 3.9: True

# %%
import jupyter
import numpy as np
import pandas as pd

print("jupyter import:", jupyter.__name__)
print("numpy:", np.__version__)
print("pandas:", pd.__version__)
# Out:
# jupyter import: jupyter
# numpy: 2.4.4
# pandas: 3.0.2
